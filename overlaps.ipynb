# %%
from numpy import load,save,array
from matplotlib.pyplot import imshow,plot,savefig,subplots,cm

# %%
data_hydrocerussite = load('Hydrocerussite.npy')[::-1]
data_cinabar_hydrocerussite = load('Cinabar_Hydricerussite.npy')[::-1]
data_cinabar = load('Cinabar.npy')[::-1]
data_lazurite = load('Lazurite.npy')[::-1]

# %%
cmap = cm.get_cmap('ocean').reversed()

fig,ax = subplots(2,2,figsize=(15,8))
ax[0,0].imshow(data_cinabar,vmax=100,cmap=cmap)
ax[1,0].imshow(data_cinabar_hydrocerussite,vmax=100,cmap=cmap)
ax[0,1].imshow(data_hydrocerussite,vmax=100,cmap=cmap)
ax[1,1].imshow(data_lazurite,vmax=100,cmap=cmap)

# %%
data=array([data_lazurite,data_cinabar_hydrocerussite])

# %%
m = data.argmin(0)

# %%
imshow(m,cmap=cmap)
